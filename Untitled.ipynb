# %%
import pandas as pd
######################### Working directory #########################
import os
os.getcwd()
os.chdir("C:\\Users\\lzhga\\Documents\\")

######################### Importing Datasets #########################
df = pd.read_csv('Concrete_Data.csv')

# %%
df.isnull().any()
# Out:
# cement          False
# slag            False
# ash             False
# water           False
# superplastic    False
# coarseagg       False
# fineagg         False
# age             False
# strength        False
# dtype: bool

# %%
df["cement"].describe()
# Out:
# count    1030.000000
# mean      281.167864
# std       104.506364
# min       102.000000
# 25%       192.375000
# 50%       272.900000
# 75%       350.000000
# max       540.000000
# Name: cement, dtype: float64

# %%
def vc(x, df):
  for i in df[x].columns:
    print(i)
    print(df[i].value_counts())
    print("\n")

# %%
vc(df.columns.values, df)
# Out:
# cement
# 362.6    20
# 425.0    20
# 251.4    15
# 310.0    14
# 446.0    14
#          ..
# 313.8     1
# 147.8     1
# 260.9     1
# 136.4     1
# 321.3     1
# Name: cement, Length: 278, dtype: int64
#
#
# slag
# 0.0      471
# 189.0     30
# 106.3     20
# 24.0      14
# 20.0      12
#         ...
# 178.1      1
# 148.9      1
# 98.8       1
# 128.9      1
# 169.4      1
# Name: slag, Length: 185, dtype: int64
#
#
# ash
# 0.0      566
# 118.3     20
# 141.0     16
# 24.5      15
# 79.0      14
#         ...
# 71.0       1
# 138.0      1
# 166.0      1
# 182.0      1
# 143.2      1
# Name: ash, Length: 156, dtype: int64
#
#
# water
# 192.0    118
# 228.0     54
# 185.7     46
# 203.5     36
# 186.0     28
#         ...
# 127.0      1
# 166.7      1
# 191.3      1
# 172.4      1
# 177.6      1
# Name: water, Length: 195, dtype: int64
#
#
# superplastic
# 0.0     379
# 11.6     37
# 8.0      27
# 7.0      19
# 6.0      17
#        ...
# 8.8       1
# 8.4       1
# 10.7      1
# 13.1      1
# 15.3      1
# Name: superplastic, Length: 111, dtype: int64
#
#
# coarseagg
# 932.0     57
# 852.1     45
# 944.7     30
# 968.0     29
# 1125.0    24
#           ..
# 820.0      1
# 908.0      1
# 981.0      1
# 923.2      1
# 838.9      1
# Name: coarseagg, Length: 284, dtype: int64
#
#
# fineagg
# 755.8    30
# 594.0    30
# 670.0    23
# 613.0    22
# 801.0    16
#          ..
# 794.0     1
# 705.0     1
# 669.0     1
# 774.3     1
# 732.6     1
# Name: fineagg, Length: 302, dtype: int64
#
#
# age
# 28     425
# 3      134
# 7      126
# 56      91
# 14      62
# 90      54
# 100     52
# 180     26
# 91      22
# 365     14
# 270     13
# 360      6
# 120      3
# 1        2
# Name: age, dtype: int64
#
#
# strength
# 33.40    6
# 71.30    4
# 41.05    4
# 31.35    4
# 23.52    4
#         ..
# 38.33    1
# 10.73    1
# 30.45    1
# 39.84    1
# 36.25    1
# Name: strength, Length: 845, dtype: int64

# %%
def countUniqueVal(dataframe, column):
    for count, name in enumerate(column):
        print("#{} - {}".format(count, name))
        print(dataframe[name].value_counts())
        print("\n")
    return
countUniqueVal(df, df.columns.values)
# Out:
# #0 - cement
# 362.6    20
# 425.0    20
# 251.4    15
# 310.0    14
# 446.0    14
#          ..
# 313.8     1
# 147.8     1
# 260.9     1
# 136.4     1
# 321.3     1
# Name: cement, Length: 278, dtype: int64
#
#
# #1 - slag
# 0.0      471
# 189.0     30
# 106.3     20
# 24.0      14
# 20.0      12
#         ...
# 178.1      1
# 148.9      1
# 98.8       1
# 128.9      1
# 169.4      1
# Name: slag, Length: 185, dtype: int64
#
#
# #2 - ash
# 0.0      566
# 118.3     20
# 141.0     16
# 24.5      15
# 79.0      14
#         ...
# 71.0       1
# 138.0      1
# 166.0      1
# 182.0      1
# 143.2      1
# Name: ash, Length: 156, dtype: int64
#
#
# #3 - water
# 192.0    118
# 228.0     54
# 185.7     46
# 203.5     36
# 186.0     28
#         ...
# 127.0      1
# 166.7      1
# 191.3      1
# 172.4      1
# 177.6      1
# Name: water, Length: 195, dtype: int64
#
#
# #4 - superplastic
# 0.0     379
# 11.6     37
# 8.0      27
# 7.0      19
# 6.0      17
#        ...
# 8.8       1
# 8.4       1
# 10.7      1
# 13.1      1
# 15.3      1
# Name: superplastic, Length: 111, dtype: int64
#
#
# #5 - coarseagg
# 932.0     57
# 852.1     45
# 944.7     30
# 968.0     29
# 1125.0    24
#           ..
# 820.0      1
# 908.0      1
# 981.0      1
# 923.2      1
# 838.9      1
# Name: coarseagg, Length: 284, dtype: int64
#
#
# #6 - fineagg
# 755.8    30
# 594.0    30
# 670.0    23
# 613.0    22
# 801.0    16
#          ..
# 794.0     1
# 705.0     1
# 669.0     1
# 774.3     1
# 732.6     1
# Name: fineagg, Length: 302, dtype: int64
#
#
# #7 - age
# 28     425
# 3      134
# 7      126
# 56      91
# 14      62
# 90      54
# 100     52
# 180     26
# 91      22
# 365     14
# 270     13
# 360      6
# 120      3
# 1        2
# Name: age, dtype: int64
#
#
# #8 - strength
# 33.40    6
# 71.30    4
# 41.05    4
# 31.35    4
# 23.52    4
#         ..
# 38.33    1
# 10.73    1
# 30.45    1
# 39.84    1
# 36.25    1
# Name: strength, Length: 845, dtype: int64

# %%
def plotDist(dataframe, column):
    sns.set(style="darkgrid")
    ax = sns.distplot(dataframe[dataframe[column].notnull()][column], norm_hist=True)

# %%
plotDist(df, "cement")

# %%
import seaborn as sns

# %%
## Duplicating/Splitting dataframes ##
categorical_columns = []
numeric_columns = []
for c in df.columns:
    if df[c].map(type).eq(str).any(): #check if there are any strings in column
        categorical_columns.append(c)
    else:
        numeric_columns.append(c)
obj_df = df.select_dtypes(include=['object']).copy() # Only select data type = object
numfloat_df = df.select_dtypes(include=['float','int64']).copy() # Only select data type = object

# %%
def split_df(df):
  categorical_columns = []
  numeric_columns = []
  for c in df.columns:
      if df[c].map(type).eq(str).any(): #check if there are any strings in column
          categorical_columns.append(c)
      else:
          numeric_columns.append(c)
  df_cat = df.select_dtypes(include=['object']).copy() # Only select data type = object
  df_cont = df.select_dtypes(include=['float','int64']).copy() # Only select data type = float/int
  return df_cont

# %%
split_df(df)
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...        ...
# 1025     44.28
# 1026     31.18
# 1027     23.70
# 1028     32.77
# 1029     32.40
#
# [1030 rows x 9 columns]

# %%
numeric_columns
# Out:
# []

# %%
def cat(df):
  categorical_columns = []
  for c in df.columns:
      if df[c].map(type).eq(str).any(): #check if there are any strings in column
          categorical_columns.append(c)
      else:
        next
  df_cat = df.select_dtypes(include=['object']).copy() # Only select data type = object
  return df_cat

# %%
def cont(df):
  numeric_columns = []
  for c in df.columns:
      if df[c].map(type).eq(str).any(): #check if there are any strings in column
        next
      else:
        numeric_columns.append(c)
  df_cont = df.select_dtypes(include=['float','int64']).copy() # Only select data type = float/int64
  return df_cont
  df_cont = cont(df)

# %%
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...        ...
# 1025     44.28
# 1026     31.18
# 1027     23.70
# 1028     32.77
# 1029     32.40
#
# [1030 rows x 9 columns]

# %%
impute_grps = df.pivot_table(values=["strength"], index=["cement", "slag"], aggfunc=np.mean)
print (impute_grps)
# Out:
#                strength
# cement slag
# 102.0  153.0  13.747500
# 108.3  162.4  14.967500
# 116.0  173.0  17.435000
# 122.6  183.9  17.787500
# 132.0  206.5  33.310000
# ...                 ...
# 522.0  0.0    62.750000
# 525.0  0.0    52.624286
# 528.0  0.0    56.830000
# 531.3  0.0    52.520000
# 540.0  0.0    64.294444
#
# [357 rows x 1 columns]

# %%
import numpy as np
